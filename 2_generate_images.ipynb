# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.8 MB/s eta 0:00:00
# ...

# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.0 MB/s eta 0:00:00
# ...

# %%
from diffusers import AutoPipelineForText2Image
import torch

pipeline_text2image = AutoPipelineForText2Image.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
).to("cuda")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
""" Prompt to ChatGPT to generate them:
Hi, please generate 50 short, conceise, understandable prompts about cars, similar to the ones from LSUN cars. The prompts will be used to generate images similar to LSUN cars.
Please make Python list of them."""

car_prompts = [
    "A red convertible cruising down a coastal highway.",
    "A vintage Volkswagen Beetle parked on a cobblestone street.",
    "A sleek black sports car speeding through a tunnel.",
    "A classic muscle car performing a burnout.",
    "An electric car charging at a futuristic station.",
    "A yellow taxi cab navigating busy city streets.",
    "A family SUV loaded with camping gear in a forest.",
    "A luxury sedan parked in front of a high-rise building.",
    "A rugged off-road vehicle conquering rocky terrain.",
    "A race car zooming around a track.",
    "A delivery van making a stop in a suburban neighborhood.",
    "A retro camper van parked by a tranquil lake.",
    "A police car chasing a suspect through downtown.",
    "A colorful parade float shaped like a car.",
    "A self-driving car navigating urban traffic.",
    "A vintage pickup truck loaded with fresh produce at a farmers market.",
    "A futuristic flying car soaring above city skyscrapers.",
    "A convertible driving through a field of sunflowers.",
    "A sleek limousine arriving at a glamorous event.",
    "A tow truck hauling a broken-down vehicle.",
    "A group of friends road-tripping in a convertible with surfboards strapped on top.",
    "A car covered in snow parked outside a cozy cabin.",
    "A car showroom filled with shiny new vehicles.",
    "A car wash bustling with activity on a sunny day.",
    "A hot rod revving its engine at a drag race.",
    "A vintage car rally winding through scenic countryside.",
    "A futuristic concept car on display at an auto expo.",
    "A school bus dropping off children on a suburban street.",
    "A convertible with a picnic basket in the trunk parked by a vineyard.",
    "A car covered in graffiti art in an urban alleyway.",
    "A vintage fire truck speeding to an emergency.",
    "A convertible driving along a winding mountain road.",
    "A group of friends tailgating in a stadium parking lot.",
    "A car submerged in a flooded street during a storm.",
    "A car covered in mud after an off-road adventure.",
    "A line of cars waiting at a drive-in movie theater.",
    "A futuristic hovercar gliding above a futuristic cityscape.",
    "A vintage ice cream truck parked at a busy beach.",
    "A car showroom filled with classic cars from different eras.",
    "A car covered in flowers for a wedding procession.",
    "A hearse leading a solemn funeral procession.",
    "A car drifting around a corner on a racetrack.",
    "A vintage convertible driving along Route 66.",
    "A car covered in holiday decorations driving through a snowy town.",
    "A group of friends tailgating before a concert.",
    "A car covered in colorful decals at a car show.",
    "A car ferry transporting vehicles across a body of water.",
    "A vintage car restoration workshop bustling with activity.",
    "A futuristic pod car transporting passengers in a city.",
    "A car showroom featuring the latest electric vehicle models."
]

# %%
""" Prompt to ChatGPT to generate them:
Thanks! Please generate also 50, but for wildlife animals.
Please make Python list of them."""

wildlife_prompts = [
    "A majestic lion resting in the shade of an acacia tree.",
    "A family of elephants crossing a dusty savanna.",
    "A group of giraffes grazing on tall trees.",
    "A leopard camouflaged among dense foliage.",
    "A herd of wildebeests migrating across the Serengeti.",
    "A pack of wolves howling under a full moon.",
    "A graceful cheetah sprinting across the plains.",
    "A solitary rhinoceros bathing in a muddy waterhole.",
    "A troupe of monkeys swinging through the jungle canopy.",
    "A colorful flock of parrots flying over a rainforest.",
    "A polar bear hunting for seals on an icy landscape.",
    "A pod of dolphins leaping out of the ocean waves.",
    "A family of meerkats standing guard near their burrow.",
    "A majestic bald eagle perched atop a tree branch.",
    "A group of penguins huddling together for warmth on an Antarctic iceberg.",
    "A playful otter sliding down a riverbank.",
    "A serene scene of deer grazing in a meadow.",
    "A school of fish swimming in a coral reef.",
    "A mother bear and her cubs fishing for salmon in a river.",
    "A pair of mountain goats scaling steep cliffs.",
    "A colorful toucan perched on a branch in a tropical forest.",
    "A swarm of bees pollinating flowers in a field.",
    "A family of ducks swimming in a tranquil pond.",
    "A regal tiger prowling through tall grass.",
    "A group of sea turtles nesting on a sandy beach.",
    "A colony of seals lounging on rocks by the ocean.",
    "A wise old owl perched in a tree at dusk.",
    "A playful dolphin jumping out of the water.",
    "A flock of flamingos wading in shallow water.",
    "A curious fox peeking out from behind bushes.",
    "A majestic humpback whale breaching the surface of the ocean.",
    "A pair of mating birds performing an elaborate courtship dance.",
    "A herd of bison grazing on a vast prairie.",
    "A family of koalas nestled in eucalyptus trees.",
    "A group of wild horses galloping across an open plain.",
    "A group of chimpanzees grooming each other in the forest.",
    "A colony of penguins marching across the Antarctic ice.",
    "A family of gorillas foraging for food in the jungle.",
    "A swarm of fireflies illuminating a forest at night.",
    "A pair of mating elk locking antlers in a display of strength.",
    "A colorful reef shark swimming among coral formations.",
    "A herd of zebras migrating across the African savanna.",
    "A group of kangaroos hopping across the Australian outback.",
    "A family of otters playing in a freshwater stream.",
    "A regal swan gliding across a serene lake.",
    "A pack of hyenas scavenging for food on the African plains.",
    "A pair of snowy owls perched on a snowy branch.",
    "A family of lemurs lounging in the treetops.",
    "A flock of seagulls soaring above crashing waves.",
    "A solitary grizzly bear fishing in a mountain stream."
]

# %%
""" Prompt to ChatGPT to generate them:
And 9 prompts to generated similar images to dataset BreCaHAD.
Please make Python list of them."""

brecahad_prompts = [
    "An image showing histological features of benign breast tissue.",
    "A microscopic view of malignant breast tumor cells under high magnification.",
    "An image depicting ductal carcinoma in situ (DCIS) in breast tissue.",
    "Histopathological features of invasive lobular carcinoma (ILC) in breast tissue.",
    "Microscopic view of infiltrating ductal carcinoma (IDC) in breast tissue.",
    "Histological features of invasive mammary carcinoma with lymph node metastasis.",
    "An image illustrating inflammatory breast cancer (IBC) in breast tissue.",
    "Microscopic view of intraductal papilloma in breast tissue.",
    "Histopathological features of atypical ductal hyperplasia (ADH) in breast tissue."
]

# %% [markdown]
# # breast cancer SD

# %%
brecahad_images_list=[]

for i, prompt in enumerate(brecahad_prompts):
  print(i)
  print(prompt)
  images = pipeline_text2image(prompt=prompt)
  brecahad_images_list.append(images.images[0])
# Out:
# 0
# An image showing histological features of benign breast tissue.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1
# A microscopic view of malignant breast tumor cells under high magnification.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2
# An image depicting ductal carcinoma in situ (DCIS) in breast tissue.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 3
# Histopathological features of invasive lobular carcinoma (ILC) in breast tissue.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 4
# An image showing fibroadenoma, a common benign breast tumor.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 5
# Microscopic view of infiltrating ductal carcinoma (IDC) in breast tissue.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 6
# Histological features of invasive mammary carcinoma with lymph node metastasis.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 7
# An image illustrating inflammatory breast cancer (IBC) in breast tissue.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 8
# ...

# %%
for i in range(len(brecahad_images_list)):
  brecahad_images_list[i].save(f"brecahad/brecahad_img_{i}.png")

# %%
with open(r'brecahad/brecahad_prompts.txt', 'w') as fp:
    for item in brecahad_prompts:
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
archived = shutil.make_archive('brecahad_zipped', 'zip', 'brecahad')

# %% [markdown]
# # cars SD

# %%
car_images_list=[]

for i, prompt in enumerate(car_prompts):
  print(i)
  print(prompt)
  images = pipeline_text2image(prompt=prompt)
  car_images_list.append(images.images[0])
# Out:
# 0
# A red convertible cruising down a coastal highway.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1
# A vintage Volkswagen Beetle parked on a cobblestone street.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2
# A sleek black sports car speeding through a tunnel.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 3
# A classic muscle car performing a burnout.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 4
# An electric car charging at a futuristic station.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 5
# A yellow taxi cab navigating busy city streets.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 6
# A family SUV loaded with camping gear in a forest.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 7
# A luxury sedan parked in front of a high-rise building.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 8
# A rugged off-road vehicle conquering rocky terrain.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 9
# A race car zooming around a track.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 10
# ...

# %%
for i in range(len(car_images_list)):
  car_images_list[i].save(f"cars/cars_img_{i}.png")

# %%
# open file in write mode
with open(r'cars/cars_prompts.txt', 'w') as fp:
    for item in car_prompts:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
archived = shutil.make_archive('cars_zipped', 'zip', 'cars')

# %% [markdown]
# # wildlife SD

# %%
wildlife_images_list=[]

for i, prompt in enumerate(wildlife_prompts):
  print(i)
  print(prompt)
  images = pipeline_text2image(prompt=prompt)
  wildlife_images_list.append(images.images[0])
# Out:
# 0
# A majestic lion resting in the shade of an acacia tree.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1
# A family of elephants crossing a dusty savanna.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2
# A group of giraffes grazing on tall trees.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 3
# A leopard camouflaged among dense foliage.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 4
# A herd of wildebeests migrating across the Serengeti.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 5
# A pack of wolves howling under a full moon.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 6
# A graceful cheetah sprinting across the plains.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 7
# A solitary rhinoceros bathing in a muddy waterhole.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 8
# A troupe of monkeys swinging through the jungle canopy.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 9
# A colorful flock of parrots flying over a rainforest.
#   0%|          | 0/50 [00:00<?, ?it/s]
# 10
# ...

# %%
for i in range(len(wildlife_images_list)):
  wildlife_images_list[i].save(f"wildlife/wildlife_img_{i}.png")

# %%
with open(r'wildlife/wildlife_prompts.txt', 'w') as fp:
    for item in wildlife_prompts:
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
archived = shutil.make_archive('wildlife_zipped', 'zip', 'wildlife')

# %% [markdown]
# # Open AI - DALL E 3

# %%
from openai import OpenAI
client = OpenAI(api_key="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") # API KEY has been disabled

response = client.images.generate(
  model="dall-e-3",
  prompt="a white siamese cat",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-aPBC54YgDgReUa6WmCNULg3N/user-c6VKAhfD3bZUVEdMKWJ67Ehv/img-Qlxx3u5iG3gCNVXo3hJRsByd.png?st=2024-03-10T16%3A08%3A02Z&se=2024-03-10T18%3A08%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-09T18%3A21%3A14Z&ske=2024-03-10T18%3A21%3A14Z&sks=b&skv=2021-08-06&sig=vGoi8Cjv0vtx5DA3AS6WUTqnohdSOx73Ku8ETkO9cEE%3D'

# %%
import base64
import io
import requests
from PIL import Image

def process_image_to_base64(url, file_name):
  response = requests.get(url)
  image_bytes = io.BytesIO(response.content)
  img = Image.open(image_bytes)
  img.save(file_name, format='PNG')

# %%
process_image_to_base64(image_url)

# %% [markdown]
# # cars DALLE

# %%
for i, prompt in enumerate(car_prompts):
  response = client.images.generate(
    model="dall-e-3",
    prompt=prompt,
    size="1024x1024",
    quality="standard",
    n=1,
  )

  image_url = response.data[0].url
  process_image_to_base64(image_url, f"dalle_cars/car_img{i}.png")

# %%
archived = shutil.make_archive('dalle_cars_zipped', 'zip', 'dalle_cars')

# %%
import time
import base64
import io
import requests
from PIL import Image
from openai import OpenAI
import shutil
import os.path

# %%
""" Prompt to ChatGPT to generate them:
Thanks! Please generate also 50, but for wildlife animals.
Please make Python list of them."""

wildlife_prompts = [
    "A majestic lion resting in the shade of an acacia tree.",
    "A family of elephants crossing a dusty savanna.",
    "A group of giraffes grazing on tall trees.",
    "A leopard camouflaged among dense foliage.",
    "A herd of wildebeests migrating across the Serengeti.",
    "A pack of wolves howling under a full moon.",
    "A graceful cheetah sprinting across the plains.",
    "A solitary rhinoceros bathing in a muddy waterhole.",
    "A troupe of monkeys swinging through the jungle canopy.",
    "A colorful flock of parrots flying over a rainforest.",
    "A polar bear hunting for seals on an icy landscape.",
    "A pod of dolphins leaping out of the ocean waves.",
    "A family of meerkats standing guard near their burrow.",
    "A majestic bald eagle perched atop a tree branch.",
    "A group of penguins huddling together for warmth on an Antarctic iceberg.",
    "A playful otter sliding down a riverbank.",
    "A serene scene of deer grazing in a meadow.",
    "A school of fish swimming in a coral reef.",
    "A mother bear and her cubs fishing for salmon in a river.",
    "A pair of mountain goats scaling steep cliffs.",
    "A colorful toucan perched on a branch in a tropical forest.",
    "A swarm of bees pollinating flowers in a field.",
    "A family of ducks swimming in a tranquil pond.",
    "A regal tiger prowling through tall grass.",
    "A group of sea turtles nesting on a sandy beach.",
    "A colony of seals lounging on rocks by the ocean.",
    "A wise old owl perched in a tree at dusk.",
    "A playful dolphin jumping out of the water.",
    "A flock of flamingos wading in shallow water.",
    "A curious fox peeking out from behind bushes.",
    "A majestic humpback whale breaching the surface of the ocean.",
    "A pair of mating birds performing an elaborate courtship dance.",
    "A herd of bison grazing on a vast prairie.",
    "A family of koalas nestled in eucalyptus trees.",
    "A group of wild horses galloping across an open plain.",
    "A group of chimpanzees grooming each other in the forest.",
    "A colony of penguins marching across the Antarctic ice.",
    "A family of gorillas foraging for food in the jungle.",
    "A swarm of fireflies illuminating a forest at night.",
    "A pair of mating elk locking antlers in a display of strength.",
    "A colorful reef shark swimming among coral formations.",
    "A herd of zebras migrating across the African savanna.",
    "A group of kangaroos hopping across the Australian outback.",
    "A family of otters playing in a freshwater stream.",
    "A regal swan gliding across a serene lake.",
    "A pack of hyenas scavenging for food on the African plains.",
    "A pair of snowy owls perched on a snowy branch.",
    "A family of lemurs lounging in the treetops.",
    "A flock of seagulls soaring above crashing waves.",
    "A solitary grizzly bear fishing in a mountain stream."
]

# %%
""" Prompt to ChatGPT to generate them:
And 9 prompts to generated similar images to dataset BreCaHAD.
Please make Python list of them."""

brecahad_prompts = [
    "An image showing histological features of benign breast tissue.",
    "A microscopic view of malignant breast tumor cells under high magnification.",
    "An image depicting ductal carcinoma in situ (DCIS) in breast tissue.",
    "Histopathological features of invasive lobular carcinoma (ILC) in breast tissue.",
    "Microscopic view of infiltrating ductal carcinoma (IDC) in breast tissue.",
    "Histological features of invasive mammary carcinoma with lymph node metastasis.",
    "An image illustrating inflammatory breast cancer (IBC) in breast tissue.",
    "Microscopic view of intraductal papilloma in breast tissue.",
    "Histopathological features of atypical ductal hyperplasia (ADH) in breast tissue."
]

# %%
client = OpenAI(api_key="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") # API KEY has been disabled

response = client.images.generate(
  model="dall-e-3",
  prompt="a white siamese cat",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

# %%
def process_image_to_base64(url, file_name):
  response = requests.get(url)
  image_bytes = io.BytesIO(response.content)
  img = Image.open(image_bytes)
  img.save(file_name, format='PNG')

# %% [markdown]
# # Wildlife DALLE

# %%
for i, prompt in enumerate(wildlife_prompts):
  if i>4:
    time.sleep(20)
    response = client.images.generate(
      model="dall-e-3",
      prompt=prompt+" I NEED to test how the tool works with extremely simple prompts. DO NOT add any detail, just use it AS-IS",
      size="1024x1024",
      quality="standard",
      n=1,
    )

    image_url = response.data[0].url
    process_image_to_base64(image_url, f"dalle_wildlife/wildlife_img_{i}.png")

# %%
archived = shutil.make_archive('dalle_wildlife_zipped', 'zip', 'dalle_wildlife')

# %% [markdown]
# # breast cancer DALLE

# %%
for i, prompt in enumerate(brecahad_prompts):
  response = client.images.generate(
    model="dall-e-3",
    prompt=prompt+" I NEED to test how the tool works with extremely simple prompts. DO NOT add any detail, just use it AS-IS",
    size="1024x1024",
    quality="standard",
    n=1,
  )

  image_url = response.data[0].url
  process_image_to_base64(image_url, f"dalle_brecahad/brecahad_img_{i}.png")

# %%
archived = shutil.make_archive('dalle_brecahad_zipped', 'zip', 'dalle_brecahad')
